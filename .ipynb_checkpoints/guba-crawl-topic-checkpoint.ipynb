# %%
# %load guba_crawl_topic.py
# -*- coding: utf-8 -*-
"""
Created on Fri Feb 23 2018

@author: zhangjoy
爬取东方财富网股吧-热门主题吧
数据文件采用csv存取
"""

import requests
from bs4 import BeautifulSoup
import csv
import time

# 获取页面内容
def getHTMLText(url):
    try:
        r = requests.get(url)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except:
        return ""

# 这里比较m_time是否大于n_time
def compare_time(m_time,n_time):
    m_time1 = time.mktime(time.strptime(m_time,'%Y-%m-%d %H:%M:%S')) 
    n_time1 = time.mktime(time.strptime(n_time,'%Y%m%d'))
    if (float(m_time1) >= float(n_time1)):
        return 1
    else:
        return 0

# 爬取热门主题吧：主题 + 网页链接
'''
    财经评论
    http://guba.eastmoney.com/list,cjpl,99_1.html
    http://guba.eastmoney.com/list,cjpl,99_2.html ...
'''
def hot_zhutiba(topic_list):
    html = getHTMLText("http://guba.eastmoney.com/remenba.aspx?type=2")    #该网址为股吧热门主题吧列表
    soup = BeautifulSoup(html,'html.parser') # 解析网页
    a1 = soup.find("div",attrs={"class":"zhutibarlist"})    #body > div:nth-child(6) > div.gbboxb > div > ul > ul > li:nth-child(1) > a
    a2 = a1.find_all("a")                                   #热门主题吧："class":"zhutibarlist"
    one = []                                                #全部主题吧："class":"allzhutilistb"
    for tr in a2:
        title = tr.text # 主题吧 名称
        href = tr.attrs["href"] # list,cjpl.html
        href = href.split('.')[0].split(",")[1] # 主题吧热贴 http://guba.eastmoney.com/list,cjpl,99.html
        one.append(title)                       #
        one.append(href)
        topic_list.append(one)
        # file = "./py_project/stock_crawl_new/topic.csv"
        # with open(file, 'a', newline="") as f:
        #     #dialect为打开csv文件的方式，默认是excel，delimiter="\t"参数指写入的时候的分隔符
        #     csvwriter = csv.writer(f,dialect = ("excel"))
        #     #csv文件插入一行数据，把下面列表中的每一项放入一个单元格（可以用循环插入多行）
        #     csvwriter.writerow(one)
        one = []
    return topic_list
'''
[[['财经评论吧', 'cjpl'], ['股市实战吧', 'gssz'], ['上证指数吧', 'szzs'], ['玉米吧', 'fdcec'], 
 ['螺纹钢吧', 'fshferb'], ['铁矿石吧', 'fdcei'], ['房地产吧', 'fdc'], ['焦炭主力吧', 'fdcejm'], 
 ['股民学校吧', 'gmxx'], ['新三板吧', 'bk0600'], ['沪金吧', 'fshfeau'], ['焦炭吧', 'fdcej'], 
 ['美元指数吧', 'zsgjudi'], ['核心内参吧', 'hxnc'], ['股指期货吧', 'gzqh'], ['创业板指吧', 'cyb'], 
 ['甲醇吧', 'fczcema'], ['橡胶吧', 'fshferu'], ['原油吧', 'yuanyou'], ['恒生指数吧', 'hkhsi'], 
 ['现货吧', 'xianhuo'], ['大话财经吧', 'dhcj'], ['新股吧', 'xg'], ['玻璃吧', 'fczcefg'], 
 ['豆粕吧', 'fdcem'], ['理财吧', 'licai'], ['白糖单吧', 'fczcesr'], ['PTA吧', 'fczceta'], 
  ['沪银吧', 'fshfeag'], ['期货吧', 'qh']]]
'''

# 获取评论的发表时间，内容
def getCommentContent(url):
    publish_time,content = "",""
    html = getHTMLText(url) # [url]"http://guba.eastmoney.com/news,cjpl,746982237.html"
    soup = BeautifulSoup(html,'html.parser')
    # title = soup.title.text.split("_")[0] # 标题
    a = soup.find("div",attrs={"id":"zwconbody"})
    # a1 = a.find("div",attrs={"id":"zw_header"})
    # come_from = a1.text.split(" ")[0].split("：")[1] # 来源
    # b1 = a.find("div",attrs={"id":"zw_body"})
    # b = a.find_all("p")
    # for tr in b:
    #     content = content + tr.text # 内容
    # content = a.text
    if a != None:
        try:      
            for string in a.stripped_strings:
                content = content + string
        except:        
            content = content + a.string
    else:
        content = "wrong"
    c = soup.find("div",attrs={"class":"zwfbtime"})
    try:
        publish_time = c.text.split(" ")[1] + " " + c.text.split(" ")[2] # 发表时间 发表于 2018-02-24 08:42:00
    except:
        publish_time = c.text.split(" ")[0].split("：")[1] + " " + c.text.split(" ")[1] # 发表于：2018-02-26 10:53:04
    return publish_time,content

# 获取评论信息
def getCommentInfo(start_url,file,page,start,end,topic_bar,topic_url):
    flag = 1
    html = getHTMLText(start_url) # 热帖开始网址 http://guba.eastmoney.com/list,cjpl,99.html
    soup = BeautifulSoup(html,'html.parser')
    # header
    # a1 = soup.find("div",attrs={"class":"dheader"})
    # header_list = [] # ['阅读', '评论', '标题', '作者', '发表日期', '最后更新']
    # a2 = a1.find_all("span")
    # for tr in a2:
    #     header = tr.text
    #     header_list.append(header)
    # # 获取帖子['阅读', '评论', '标题', '作者', '发表日期', '最后更新']
    Oneinfo = []
    count = 0
    b1 = soup.find_all("div",attrs={"class":"articleh"})
    if b1 != None:
        for tr in b1:
            t1 = time.time()
            count = count + 1
            read_num = tr.find("span",attrs={"class":"l1"}).text
            comment_num = tr.find("span",attrs={"class":"l2"}).text
            title = tr.find("span",attrs={"class":"l3"}).text
            content_url = "http://guba.eastmoney.com" + tr.find("span",attrs={"class":"l3"}).a.attrs["href"]
            publish_time,content = getCommentContent(content_url)
            author = tr.find("span",attrs={"class":"l4"}).text
            # publish_time = tr.find("span",attrs={"class":"l5"}).text # 没有年份
            # latest_time = tr.find("span",attrs={"class":"l6"}).text

            # 根据发帖时间判断是否需要爬取下一页以及是否需要爬取帖子标题和内容
            time_fit1 = compare_time(publish_time,start) # > :1 晚 else:0 早
            time_fit2 = compare_time(publish_time,end)   # > :1 晚 else:0 早

            # 当前帖子的发帖时间小于爬取开始时间，不需要继续爬取下一页评论列表，设置flag=0
            if time_fit1 == 0:
                flag = 0
            else:
                flag = 1

            #当前帖子的发帖时间处于爬取时间段内，对帖子标题和内容进行爬取
            if time_fit1 == 1 and time_fit2 == 0:
                Oneinfo.append(["page_"+str(page),count]) # 页面信息
                Oneinfo.append(title) # 评论标题
                Oneinfo.append(author) # 发表作者
                Oneinfo.append(publish_time) # 发表时间
                Oneinfo.append(read_num) # 阅读量
                Oneinfo.append(comment_num) # 评论量
                Oneinfo.append(content_url) # 内容链接: http://guba.eastmoney.com/news,cjpl,743193430.html
                Oneinfo.append(content) # 评论内容
                # Oneinfo.append(latest_time) # 最后更新时间
                with open(file, 'a', newline="", encoding='gb18030') as f: # ,encoding="gb18030"
                    # dialect为打开csv文件的方式，默认是excel，delimiter="\t"参数指写入的时候的分隔符
                    csvwriter = csv.writer(f,dialect = ("excel"))
                    # csv文件插入一行数据，把下面列表中的每一项放入一个单元格（可以用循环插入多行）
                    csvwriter.writerow(Oneinfo)
                t2 = time.time()
                print(topic_bar,"p"+str(page),count,"In and Crawling success,time using %.5f s" %(t2-t1))
                Oneinfo = []
            else:
                print(topic_bar,"p"+str(page),count,"Out")
    else:
        flag = 0

    if flag == 1:
        return "http://guba.eastmoney.com/list," + topic_url + ",99,f_" + str(page+1) + ".html"  
    else:
        return ""

    '''                 
    <span class="l1">14462545</span>
    <span class="l2">231</span>
    <span class="l3"><a href="/news,cjpl,743193430.html" title="1分钟股票开户立享多重惊喜：超低佣金，另有5大豪礼等你拿！" >1分钟股票开户立享多重惊喜：超低佣金，另有5大</a></span>
    <span class="l4"><a href="http://iguba.eastmoney.com/6712111507146464"  data-popper="6712111507146464" data-poptype="1" target="_blank">东方财富网</a><input type="hidden" value="31000" /><a href=" http://v2.eastmoney.com"><em class="lv" title="东方财富机构认证"></em></a></span>
    <span class="l6">01-25</span>
    <span class="l5">02-24 12:12</span>
    '''

#主函数
def main():   
    topic_list = []
    hot_zhutiba(topic_list) # 获取主题吧名称 链接
    start = '20180601'  # 设置爬取开始时间
    end = '20180605'  # 设置爬取结束时间,不包含此日

    time1 = time.time()
    for i in range(0,1): # len(topic_list)
        time3 = time.time()
        page = 1  # 财经评论吧 page42-49 即发表于2月27日 + 2月28日 的全部评论 
        # 2016:2525[2550 4]/2482/2435/2360/2264/2179/2109/2038/1980/
        # 2017:1935[start 1]/1887/1828/1769/1703/1644/1559/1419/1137/
        # [2017.10]925/608/323/
        # 2018:152/68/
        topic_bar = topic_list[i][0]
        topic_url = topic_list[i][-1]
        file = "D:\\Program Files\\Git\\git_work\\demo-topic-model\\" + start + "_" + end + "_cjpl.csv"        #设置评论内容的存储路径 
        start_url = "http://guba.eastmoney.com/list," + topic_url + ",99,f_" + str(page) + ".html"
        # http://guba.eastmoney.com/list,cjpl,99_1.html   按评论时间排序
        # http://guba.eastmoney.com/list,cjpl,99,f_1.html 按发帖时间排序
        print("------------------- Start Crawl -------------------")
        with open(file, 'a', newline="", encoding='gb18030') as f:
            csvwriter = csv.writer(f,dialect = ("excel"))
            csvwriter.writerow(["页面信息","评论标题","发表作者","发表时间","阅读量","评论量","内容链接","评论内容"])
        while True: 
            if start_url != "":              
                start_url = getCommentInfo(start_url,file,page,start,end,topic_bar,topic_url)        
                page = page + 1
            else:
                print("已完成topic " + topic_bar + " " + start + "-" + end + "的评论爬取")
                break
        time4 = time.time()
        m, s = divmod(time4-time3, 60)
        h, m = divmod(m, 60)
        print("topic " + topic_bar + " all time using %02d:%02d:%02d" % (h, m, s))
        print("------------------- End   Crawl -------------------")
        time2 = time.time()
        m, s = divmod(time2-time1, 60)
        h, m = divmod(m, 60)
        print ("all time using %02d:%02d:%02d" % (h, m, s))

main()
# Out:
# ------------------- Start Crawl -------------------
# 财经评论吧 p1 1 In and Crawling success,time using 0.92449 s
# 财经评论吧 p1 2 In and Crawling success,time using 0.75730 s
# 财经评论吧 p1 3 In and Crawling success,time using 1.23103 s
# 财经评论吧 p1 4 In and Crawling success,time using 0.92917 s
# 财经评论吧 p1 5 In and Crawling success,time using 0.89377 s
# 财经评论吧 p1 6 In and Crawling success,time using 0.54845 s
# 财经评论吧 p1 7 In and Crawling success,time using 0.59351 s
# 财经评论吧 p1 8 In and Crawling success,time using 0.67972 s
# 财经评论吧 p1 9 In and Crawling success,time using 1.10699 s
# 财经评论吧 p1 10 In and Crawling success,time using 0.91924 s
# 财经评论吧 p1 11 In and Crawling success,time using 1.41648 s
# 财经评论吧 p1 12 In and Crawling success,time using 0.69022 s
# 财经评论吧 p1 13 In and Crawling success,time using 0.60585 s
# 财经评论吧 p1 14 In and Crawling success,time using 0.92652 s
# 财经评论吧 p1 15 In and Crawling success,time using 0.98695 s
# 财经评论吧 p1 16 In and Crawling success,time using 1.08789 s
# 财经评论吧 p1 17 In and Crawling success,time using 1.32527 s
# 财经评论吧 p1 18 In and Crawling success,time using 1.03866 s
# 财经评论吧 p1 19 In and Crawling success,time using 0.80164 s
# 财经评论吧 p1 20 In and Crawling success,time using 0.57212 s
# 财经评论吧 p1 21 In and Crawling success,time using 0.57604 s
# 财经评论吧 p1 22 In and Crawling success,time using 1.26662 s
# 财经评论吧 p1 23 In and Crawling success,time using 1.06481 s
# 财经评论吧 p1 24 In and Crawling success,time using 0.59319 s
# 财经评论吧 p1 25 In and Crawling success,time using 0.72971 s
# 财经评论吧 p1 26 In and Crawling success,time using 0.86811 s
# 财经评论吧 p1 27 In and Crawling success,time using 0.92273 s
# 财经评论吧 p1 28 In and Crawling success,time using 0.83317 s
# 财经评论吧 p1 29 In and Crawling success,time using 1.13621 s
# 财经评论吧 p1 30 In and Crawling success,time using 0.78363 s
# 财经评论吧 p1 31 In and Crawling success,time using 0.89602 s
# 财经评论吧 p1 32 In and Crawling success,time using 1.10550 s
# 财经评论吧 p1 33 In and Crawling success,time using 0.73734 s
# 财经评论吧 p1 34 In and Crawling success,time using 1.17543 s
# 财经评论吧 p1 35 In and Crawling success,time using 1.32034 s
# 财经评论吧 p1 36 In and Crawling success,time using 0.61194 s
# 财经评论吧 p1 37 In and Crawling success,time using 0.95119 s
# 财经评论吧 p1 38 In and Crawling success,time using 1.41631 s
# 财经评论吧 p1 39 In and Crawling success,time using 0.99524 s
# 财经评论吧 p1 40 In and Crawling success,time using 1.34141 s
# 财经评论吧 p1 41 In and Crawling success,time using 1.27043 s
# 财经评论吧 p1 42 In and Crawling success,time using 0.63992 s
# 财经评论吧 p1 43 In and Crawling success,time using 1.31700 s
# 财经评论吧 p1 44 In and Crawling success,time using 1.44597 s
# 财经评论吧 p1 45 In and Crawling success,time using 0.93211 s
# 财经评论吧 p1 46 In and Crawling success,time using 0.97545 s
# 财经评论吧 p1 47 In and Crawling success,time using 1.11515 s
# 财经评论吧 p1 48 In and Crawling success,time using 1.26437 s
# 财经评论吧 p1 49 In and Crawling success,time using 1.56911 s
# 财经评论吧 p1 50 In and Crawling success,time using 1.30998 s
# 财经评论吧 p1 51 In and Crawling success,time using 0.83494 s
# 财经评论吧 p1 52 In and Crawling success,time using 0.61855 s
# 财经评论吧 p1 53 In and Crawling success,time using 0.64404 s
# 财经评论吧 p1 54 In and Crawling success,time using 0.85635 s
# 财经评论吧 p1 55 In and Crawling success,time using 0.75222 s
# 财经评论吧 p1 56 In and Crawling success,time using 0.66752 s
# 财经评论吧 p1 57 In and Crawling success,time using 0.91502 s
# 财经评论吧 p1 58 In and Crawling success,time using 1.16352 s
# 财经评论吧 p1 59 In and Crawling success,time using 0.83610 s
# 财经评论吧 p1 60 In and Crawling success,time using 0.94255 s
# 财经评论吧 p1 61 In and Crawling success,time using 0.81505 s
# 财经评论吧 p1 62 In and Crawling success,time using 1.13703 s
# 财经评论吧 p1 63 In and Crawling success,time using 0.71704 s
# 财经评论吧 p1 64 In and Crawling success,time using 1.14180 s
# 财经评论吧 p1 65 In and Crawling success,time using 0.88790 s
# 财经评论吧 p1 66 In and Crawling success,time using 0.60786 s
# 财经评论吧 p1 67 In and Crawling success,time using 0.91027 s
# 财经评论吧 p1 68 In and Crawling success,time using 1.19119 s
# 财经评论吧 p1 69 In and Crawling success,time using 1.13292 s
# 财经评论吧 p1 70 In and Crawling success,time using 0.98266 s
# 财经评论吧 p1 71 In and Crawling success,time using 0.73957 s
# 财经评论吧 p1 72 In and Crawling success,time using 0.77078 s
# 财经评论吧 p1 73 In and Crawling success,time using 0.96002 s
# 财经评论吧 p1 74 In and Crawling success,time using 0.87246 s
# 财经评论吧 p1 75 In and Crawling success,time using 1.01059 s
# 财经评论吧 p1 76 In and Crawling success,time using 1.14143 s
# 财经评论吧 p1 77 In and Crawling success,time using 1.26292 s
# 财经评论吧 p1 78 In and Crawling success,time using 1.03909 s
# 财经评论吧 p1 79 In and Crawling success,time using 1.18968 s
# 财经评论吧 p1 80 In and Crawling success,time using 0.87261 s
# 财经评论吧 p2 1 In and Crawling success,time using 1.13002 s
# 财经评论吧 p2 2 In and Crawling success,time using 1.07693 s
# 财经评论吧 p2 3 In and Crawling success,time using 0.78950 s
# 财经评论吧 p2 4 In and Crawling success,time using 0.61188 s
# 财经评论吧 p2 5 In and Crawling success,time using 1.00002 s
# 财经评论吧 p2 6 In and Crawling success,time using 0.87269 s
# 财经评论吧 p2 7 In and Crawling success,time using 0.75601 s
# 财经评论吧 p2 8 In and Crawling success,time using 0.98366 s
# 财经评论吧 p2 9 In and Crawling success,time using 1.24521 s
# 财经评论吧 p2 10 In and Crawling success,time using 1.06030 s
# 财经评论吧 p2 11 In and Crawling success,time using 0.66275 s
# 财经评论吧 p2 12 In and Crawling success,time using 1.13670 s
# 财经评论吧 p2 13 In and Crawling success,time using 1.38322 s
# 财经评论吧 p2 14 In and Crawling success,time using 0.77219 s
# 财经评论吧 p2 15 In and Crawling success,time using 0.68170 s
# 财经评论吧 p2 16 In and Crawling success,time using 0.85451 s
# 财经评论吧 p2 17 In and Crawling success,time using 1.06023 s
# 财经评论吧 p2 18 In and Crawling success,time using 0.90170 s
# 财经评论吧 p2 19 In and Crawling success,time using 0.92039 s
# 财经评论吧 p2 20 In and Crawling success,time using 1.07674 s
# 财经评论吧 p2 21 In and Crawling success,time using 1.63744 s
# 财经评论吧 p2 22 In and Crawling success,time using 1.13286 s
# 财经评论吧 p2 23 In and Crawling success,time using 0.90302 s
# 财经评论吧 p2 24 In and Crawling success,time using 1.39915 s
# 财经评论吧 p2 25 In and Crawling success,time using 0.70642 s
# 财经评论吧 p2 26 In and Crawling success,time using 1.54155 s
# 财经评论吧 p2 27 In and Crawling success,time using 0.98815 s
# 财经评论吧 p2 28 In and Crawling success,time using 1.06476 s
# 财经评论吧 p2 29 In and Crawling success,time using 0.76719 s
# 财经评论吧 p2 30 In and Crawling success,time using 1.09904 s
# 财经评论吧 p2 31 In and Crawling success,time using 0.97466 s
# 财经评论吧 p2 32 In and Crawling success,time using 1.15875 s
# 财经评论吧 p2 33 In and Crawling success,time using 0.89705 s
# 财经评论吧 p2 34 In and Crawling success,time using 1.07199 s
# 财经评论吧 p2 35 In and Crawling success,time using 0.92314 s
# 财经评论吧 p2 36 In and Crawling success,time using 0.58038 s
# 财经评论吧 p2 37 In and Crawling success,time using 0.77478 s
# 财经评论吧 p2 38 In and Crawling success,time using 0.87290 s
# 财经评论吧 p2 39 In and Crawling success,time using 0.72996 s
# 财经评论吧 p2 40 In and Crawling success,time using 0.72235 s
# 财经评论吧 p2 41 In and Crawling success,time using 4.22537 s
# 财经评论吧 p2 42 In and Crawling success,time using 0.68253 s
# 财经评论吧 p2 43 In and Crawling success,time using 0.78227 s
# 财经评论吧 p2 44 In and Crawling success,time using 1.09012 s
# 财经评论吧 p2 45 In and Crawling success,time using 1.43599 s
# 财经评论吧 p2 46 In and Crawling success,time using 0.93831 s
# 财经评论吧 p2 47 In and Crawling success,time using 0.83776 s
# 财经评论吧 p2 48 In and Crawling success,time using 1.80796 s
# 财经评论吧 p2 49 In and Crawling success,time using 1.74246 s
# 财经评论吧 p2 50 In and Crawling success,time using 1.10533 s
# 财经评论吧 p2 51 In and Crawling success,time using 0.57601 s
# 财经评论吧 p2 52 In and Crawling success,time using 5.75279 s
# 财经评论吧 p2 53 In and Crawling success,time using 1.06252 s
# 财经评论吧 p2 54 In and Crawling success,time using 0.84011 s
# 财经评论吧 p2 55 In and Crawling success,time using 0.88468 s
# 财经评论吧 p2 56 In and Crawling success,time using 0.66174 s
# 财经评论吧 p2 57 In and Crawling success,time using 0.95843 s
# 财经评论吧 p2 58 In and Crawling success,time using 1.00325 s
# 财经评论吧 p2 59 In and Crawling success,time using 0.76858 s
# 财经评论吧 p2 60 In and Crawling success,time using 1.09479 s
# 财经评论吧 p2 61 In and Crawling success,time using 1.01743 s
# 财经评论吧 p2 62 In and Crawling success,time using 1.20736 s
# 财经评论吧 p2 63 In and Crawling success,time using 0.80299 s
# 财经评论吧 p2 64 In and Crawling success,time using 0.70181 s
# 财经评论吧 p2 65 In and Crawling success,time using 0.84617 s
# 财经评论吧 p2 66 In and Crawling success,time using 0.75385 s
# 财经评论吧 p2 67 In and Crawling success,time using 0.87474 s
# 财经评论吧 p2 68 In and Crawling success,time using 1.08432 s
# 财经评论吧 p2 69 In and Crawling success,time using 0.81351 s
# 财经评论吧 p2 70 In and Crawling success,time using 1.26570 s
# 财经评论吧 p2 71 In and Crawling success,time using 1.76432 s
# 财经评论吧 p2 72 In and Crawling success,time using 1.09169 s
# 财经评论吧 p2 73 In and Crawling success,time using 0.88232 s
# 财经评论吧 p2 74 In and Crawling success,time using 0.89549 s
# 财经评论吧 p2 75 In and Crawling success,time using 0.75602 s
# 财经评论吧 p2 76 In and Crawling success,time using 0.91755 s
# 财经评论吧 p2 77 In and Crawling success,time using 0.77298 s
# 财经评论吧 p2 78 In and Crawling success,time using 1.21002 s
# 财经评论吧 p2 79 In and Crawling success,time using 1.44378 s
# 财经评论吧 p2 80 In and Crawling success,time using 1.50589 s
# 财经评论吧 p3 1 In and Crawling success,time using 0.64543 s
# 财经评论吧 p3 2 In and Crawling success,time using 1.52008 s
# 财经评论吧 p3 3 In and Crawling success,time using 1.18621 s
# 财经评论吧 p3 4 In and Crawling success,time using 1.14788 s
# 财经评论吧 p3 5 In and Crawling success,time using 1.07276 s
# 财经评论吧 p3 6 In and Crawling success,time using 1.13712 s
# 财经评论吧 p3 7 In and Crawling success,time using 0.96696 s
# 财经评论吧 p3 8 In and Crawling success,time using 0.92161 s
# 财经评论吧 p3 9 In and Crawling success,time using 1.38632 s
# 财经评论吧 p3 10 In and Crawling success,time using 1.00393 s
# 财经评论吧 p3 11 In and Crawling success,time using 0.79716 s
# 财经评论吧 p3 12 In and Crawling success,time using 1.19727 s
# 财经评论吧 p3 13 In and Crawling success,time using 1.29801 s
# 财经评论吧 p3 14 In and Crawling success,time using 0.73636 s
# 财经评论吧 p3 15 In and Crawling success,time using 1.34579 s
# 财经评论吧 p3 16 In and Crawling success,time using 0.80485 s
# 财经评论吧 p3 17 In and Crawling success,time using 0.53227 s
# 财经评论吧 p3 18 In and Crawling success,time using 0.98890 s
# 财经评论吧 p3 19 In and Crawling success,time using 0.61220 s
# 财经评论吧 p3 20 In and Crawling success,time using 1.23895 s
# 财经评论吧 p3 21 In and Crawling success,time using 1.05174 s
# 财经评论吧 p3 22 In and Crawling success,time using 1.08078 s
# 财经评论吧 p3 23 In and Crawling success,time using 1.00571 s
# 财经评论吧 p3 24 In and Crawling success,time using 0.86332 s
# 财经评论吧 p3 25 In and Crawling success,time using 0.88840 s
# 财经评论吧 p3 26 In and Crawling success,time using 1.29489 s
# 财经评论吧 p3 27 In and Crawling success,time using 1.18764 s
# 财经评论吧 p3 28 In and Crawling success,time using 1.08027 s
# 财经评论吧 p3 29 In and Crawling success,time using 1.11904 s
# 财经评论吧 p3 30 In and Crawling success,time using 1.01388 s
# 财经评论吧 p3 31 In and Crawling success,time using 0.79348 s
# 财经评论吧 p3 32 In and Crawling success,time using 0.88700 s
# 财经评论吧 p3 33 In and Crawling success,time using 0.84403 s
# 财经评论吧 p3 34 In and Crawling success,time using 0.71178 s
# 财经评论吧 p3 35 In and Crawling success,time using 1.37328 s
# 财经评论吧 p3 36 In and Crawling success,time using 0.82002 s
# 财经评论吧 p3 37 In and Crawling success,time using 0.87839 s
# 财经评论吧 p3 38 In and Crawling success,time using 0.91943 s
# 财经评论吧 p3 39 In and Crawling success,time using 2.02415 s
# 财经评论吧 p3 40 In and Crawling success,time using 0.70401 s
# 财经评论吧 p3 41 In and Crawling success,time using 0.70401 s
# 财经评论吧 p3 42 In and Crawling success,time using 0.90802 s
# 财经评论吧 p3 43 In and Crawling success,time using 0.81228 s
# 财经评论吧 p3 44 In and Crawling success,time using 0.74376 s
# 财经评论吧 p3 45 In and Crawling success,time using 1.14029 s
# 财经评论吧 p3 46 In and Crawling success,time using 1.00753 s
# 财经评论吧 p3 47 In and Crawling success,time using 0.70802 s
# 财经评论吧 p3 48 In and Crawling success,time using 1.07519 s
# 财经评论吧 p3 49 In and Crawling success,time using 1.34511 s
# 财经评论吧 p3 50 In and Crawling success,time using 0.77293 s
# 财经评论吧 p3 51 In and Crawling success,time using 0.98263 s
# 财经评论吧 p3 52 In and Crawling success,time using 0.90481 s
# 财经评论吧 p3 53 In and Crawling success,time using 1.00571 s
# 财经评论吧 p3 54 In and Crawling success,time using 0.82567 s
# 财经评论吧 p3 55 In and Crawling success,time using 0.92418 s
# 财经评论吧 p3 56 In and Crawling success,time using 1.23593 s
# 财经评论吧 p3 57 In and Crawling success,time using 0.64000 s
# 财经评论吧 p3 58 In and Crawling success,time using 0.96012 s
# 财经评论吧 p3 59 In and Crawling success,time using 0.72351 s
# 财经评论吧 p3 60 In and Crawling success,time using 1.21670 s
# 财经评论吧 p3 61 In and Crawling success,time using 0.68019 s
# 财经评论吧 p3 62 In and Crawling success,time using 0.87828 s
# 财经评论吧 p3 63 In and Crawling success,time using 0.88074 s
# 财经评论吧 p3 64 In and Crawling success,time using 0.89616 s
# 财经评论吧 p3 65 In and Crawling success,time using 0.78981 s
# 财经评论吧 p3 66 In and Crawling success,time using 0.80316 s
# 财经评论吧 p3 67 In and Crawling success,time using 0.98084 s
# 财经评论吧 p3 68 In and Crawling success,time using 0.62539 s
# 财经评论吧 p3 69 In and Crawling success,time using 1.04262 s
# 财经评论吧 p3 70 In and Crawling success,time using 0.90078 s
# 财经评论吧 p3 71 In and Crawling success,time using 1.17451 s
# 财经评论吧 p3 72 In and Crawling success,time using 0.86424 s
# 财经评论吧 p3 73 In and Crawling success,time using 1.00220 s
# 财经评论吧 p3 74 In and Crawling success,time using 0.81780 s
# 财经评论吧 p3 75 In and Crawling success,time using 1.33331 s
# 财经评论吧 p3 76 In and Crawling success,time using 0.81995 s
# 财经评论吧 p3 77 In and Crawling success,time using 0.73001 s
# 财经评论吧 p3 78 In and Crawling success,time using 1.06433 s
# 财经评论吧 p3 79 In and Crawling success,time using 0.94281 s
# 财经评论吧 p3 80 In and Crawling success,time using 1.29841 s
# 财经评论吧 p4 1 In and Crawling success,time using 1.07464 s
# 财经评论吧 p4 2 In and Crawling success,time using 0.56196 s
# 财经评论吧 p4 3 In and Crawling success,time using 0.69954 s
# 财经评论吧 p4 4 In and Crawling success,time using 0.97287 s
# 财经评论吧 p4 5 In and Crawling success,time using 1.06208 s
# 财经评论吧 p4 6 In and Crawling success,time using 0.92077 s
# 财经评论吧 p4 7 In and Crawling success,time using 0.78645 s
# 财经评论吧 p4 8 In and Crawling success,time using 0.77273 s
# 财经评论吧 p4 9 In and Crawling success,time using 1.10393 s
# 财经评论吧 p4 10 In and Crawling success,time using 0.71590 s
# 财经评论吧 p4 11 In and Crawling success,time using 0.71355 s
# 财经评论吧 p4 12 In and Crawling success,time using 0.60906 s
# 财经评论吧 p4 13 In and Crawling success,time using 0.93047 s
# 财经评论吧 p4 14 In and Crawling success,time using 0.68584 s
# 财经评论吧 p4 15 In and Crawling success,time using 0.94997 s
# 财经评论吧 p4 16 In and Crawling success,time using 0.58738 s
# 财经评论吧 p4 17 In and Crawling success,time using 0.88486 s
# 财经评论吧 p4 18 In and Crawling success,time using 0.54053 s
# 财经评论吧 p4 19 In and Crawling success,time using 1.13209 s
# 财经评论吧 p4 20 In and Crawling success,time using 0.83201 s
# 财经评论吧 p4 21 In and Crawling success,time using 0.67352 s
# 财经评论吧 p4 22 In and Crawling success,time using 0.74204 s
# 财经评论吧 p4 23 In and Crawling success,time using 0.76002 s
# 财经评论吧 p4 24 In and Crawling success,time using 0.73120 s
# 财经评论吧 p4 25 In and Crawling success,time using 1.04051 s
# 财经评论吧 p4 26 In and Crawling success,time using 1.17413 s
# 财经评论吧 p4 27 In and Crawling success,time using 0.64809 s
# 财经评论吧 p4 28 In and Crawling success,time using 0.72340 s
# 财经评论吧 p4 29 In and Crawling success,time using 1.08877 s
# 财经评论吧 p4 30 In and Crawling success,time using 2.15627 s
# 财经评论吧 p4 31 In and Crawling success,time using 0.98440 s
# 财经评论吧 p4 32 In and Crawling success,time using 0.89873 s
# 财经评论吧 p4 33 In and Crawling success,time using 0.90540 s
# 财经评论吧 p4 34 In and Crawling success,time using 0.75904 s
# 财经评论吧 p4 35 In and Crawling success,time using 0.77994 s
# 财经评论吧 p4 36 In and Crawling success,time using 0.81162 s
# 财经评论吧 p4 37 In and Crawling success,time using 0.94388 s
# 财经评论吧 p4 38 In and Crawling success,time using 0.69650 s
# 财经评论吧 p4 39 In and Crawling success,time using 1.02658 s
# 财经评论吧 p4 40 In and Crawling success,time using 0.61375 s
# 财经评论吧 p4 41 In and Crawling success,time using 0.85807 s
# 财经评论吧 p4 42 In and Crawling success,time using 0.59032 s
# 财经评论吧 p4 43 In and Crawling success,time using 0.65085 s
# 财经评论吧 p4 44 In and Crawling success,time using 0.60137 s
# 财经评论吧 p4 45 In and Crawling success,time using 0.88178 s
# 财经评论吧 p4 46 In and Crawling success,time using 0.59203 s
# 财经评论吧 p4 47 In and Crawling success,time using 0.58055 s
# 财经评论吧 p4 48 In and Crawling success,time using 1.49266 s
# 财经评论吧 p4 49 In and Crawling success,time using 0.82002 s
# 财经评论吧 p4 50 In and Crawling success,time using 1.08802 s
# 财经评论吧 p4 51 In and Crawling success,time using 0.47161 s
# 财经评论吧 p4 52 In and Crawling success,time using 0.85568 s
# 财经评论吧 p4 53 In and Crawling success,time using 0.81202 s
# 财经评论吧 p4 54 In and Crawling success,time using 1.11423 s
# 财经评论吧 p4 55 In and Crawling success,time using 0.64806 s
# 财经评论吧 p4 56 In and Crawling success,time using 0.66314 s
# 财经评论吧 p4 57 In and Crawling success,time using 0.62698 s
# 财经评论吧 p4 58 In and Crawling success,time using 0.77594 s
# 财经评论吧 p4 59 In and Crawling success,time using 2.38605 s
# 财经评论吧 p4 60 In and Crawling success,time using 1.13514 s
# 财经评论吧 p4 61 In and Crawling success,time using 0.65230 s
# 财经评论吧 p4 62 In and Crawling success,time using 0.99185 s
# 财经评论吧 p4 63 In and Crawling success,time using 0.50722 s
# 财经评论吧 p4 64 In and Crawling success,time using 0.70936 s
# 财经评论吧 p4 65 In and Crawling success,time using 0.87776 s
# 财经评论吧 p4 66 In and Crawling success,time using 0.55975 s
# 财经评论吧 p4 67 In and Crawling success,time using 0.65297 s
# 财经评论吧 p4 68 In and Crawling success,time using 0.66725 s
# 财经评论吧 p4 69 In and Crawling success,time using 0.75001 s
# 财经评论吧 p4 70 In and Crawling success,time using 0.64119 s
# 财经评论吧 p4 71 In and Crawling success,time using 0.83134 s
# 财经评论吧 p4 72 In and Crawling success,time using 0.71434 s
# 财经评论吧 p4 73 In and Crawling success,time using 0.95452 s
# 财经评论吧 p4 74 In and Crawling success,time using 0.92661 s
# 财经评论吧 p4 75 In and Crawling success,time using 0.47099 s
# 财经评论吧 p4 76 In and Crawling success,time using 0.75734 s
# 财经评论吧 p4 77 In and Crawling success,time using 0.78002 s
# 财经评论吧 p4 78 In and Crawling success,time using 0.96020 s
# 财经评论吧 p4 79 In and Crawling success,time using 0.77717 s
# 财经评论吧 p4 80 In and Crawling success,time using 0.50792 s
# 财经评论吧 p5 1 In and Crawling success,time using 0.49001 s
# 财经评论吧 p5 2 In and Crawling success,time using 0.53769 s
# 财经评论吧 p5 3 In and Crawling success,time using 0.61470 s
# 财经评论吧 p5 4 In and Crawling success,time using 0.53635 s
# 财经评论吧 p5 5 In and Crawling success,time using 0.58175 s
# 财经评论吧 p5 6 In and Crawling success,time using 0.86002 s
# 财经评论吧 p5 7 In and Crawling success,time using 1.16343 s
# 财经评论吧 p5 8 In and Crawling success,time using 0.64241 s
# 财经评论吧 p5 9 In and Crawling success,time using 1.15293 s
# 财经评论吧 p5 10 In and Crawling success,time using 0.81513 s
# 财经评论吧 p5 11 In and Crawling success,time using 0.71254 s
# 财经评论吧 p5 12 In and Crawling success,time using 0.74232 s
# 财经评论吧 p5 13 In and Crawling success,time using 1.11487 s
# 财经评论吧 p5 14 In and Crawling success,time using 1.20386 s
# 财经评论吧 p5 15 In and Crawling success,time using 0.94001 s
# 财经评论吧 p5 16 In and Crawling success,time using 0.71626 s
# 财经评论吧 p5 17 In and Crawling success,time using 1.00187 s
# 财经评论吧 p5 18 In and Crawling success,time using 0.99672 s
# 财经评论吧 p5 19 In and Crawling success,time using 1.36530 s
# 财经评论吧 p5 20 In and Crawling success,time using 1.33544 s
# 财经评论吧 p5 21 In and Crawling success,time using 0.79804 s
# 财经评论吧 p5 22 In and Crawling success,time using 0.73663 s
# 财经评论吧 p5 23 In and Crawling success,time using 0.70002 s
# 财经评论吧 p5 24 In and Crawling success,time using 0.65398 s
# 财经评论吧 p5 25 In and Crawling success,time using 0.95975 s
# 财经评论吧 p5 26 In and Crawling success,time using 0.89749 s
# 财经评论吧 p5 27 In and Crawling success,time using 0.80655 s
# 财经评论吧 p5 28 In and Crawling success,time using 1.04233 s
# 财经评论吧 p5 29 In and Crawling success,time using 0.71890 s
# 财经评论吧 p5 30 In and Crawling success,time using 0.74472 s
# 财经评论吧 p5 31 In and Crawling success,time using 0.84386 s
# 财经评论吧 p5 32 In and Crawling success,time using 0.95603 s
# 财经评论吧 p5 33 In and Crawling success,time using 0.72989 s
# 财经评论吧 p5 34 In and Crawling success,time using 1.27633 s
# 财经评论吧 p5 35 In and Crawling success,time using 1.06581 s
# 财经评论吧 p5 36 In and Crawling success,time using 0.89124 s
# 财经评论吧 p5 37 In and Crawling success,time using 0.75173 s
# 财经评论吧 p5 38 In and Crawling success,time using 0.92146 s
# 财经评论吧 p5 39 In and Crawling success,time using 1.03014 s
# 财经评论吧 p5 40 In and Crawling success,time using 1.17968 s
# 财经评论吧 p5 41 In and Crawling success,time using 1.27168 s
# 财经评论吧 p5 42 In and Crawling success,time using 1.11058 s
# 财经评论吧 p5 43 In and Crawling success,time using 1.25603 s
# 财经评论吧 p5 44 In and Crawling success,time using 1.11600 s
# 财经评论吧 p5 45 In and Crawling success,time using 1.36003 s
# 财经评论吧 p5 46 In and Crawling success,time using 0.82002 s
# 财经评论吧 p5 47 In and Crawling success,time using 1.10803 s
# 财经评论吧 p5 48 In and Crawling success,time using 1.19602 s
# 财经评论吧 p5 49 In and Crawling success,time using 0.73602 s
# 财经评论吧 p5 50 In and Crawling success,time using 0.89602 s
# 财经评论吧 p5 51 In and Crawling success,time using 0.80002 s
# 财经评论吧 p5 52 In and Crawling success,time using 1.34403 s
# 财经评论吧 p5 53 In and Crawling success,time using 1.64003 s
# 财经评论吧 p5 54 In and Crawling success,time using 1.12239 s
# 财经评论吧 p5 55 In and Crawling success,time using 0.76776 s
# 财经评论吧 p5 56 In and Crawling success,time using 0.63450 s
# 财经评论吧 p5 57 In and Crawling success,time using 1.02438 s
# 财经评论吧 p5 58 In and Crawling success,time using 0.83862 s
# 财经评论吧 p5 59 In and Crawling success,time using 1.02070 s
# 财经评论吧 p5 60 In and Crawling success,time using 0.70081 s
# 财经评论吧 p5 61 In and Crawling success,time using 1.10003 s
# 财经评论吧 p5 62 In and Crawling success,time using 0.65169 s
# 财经评论吧 p5 63 In and Crawling success,time using 0.83979 s
# 财经评论吧 p5 64 In and Crawling success,time using 0.72222 s
# 财经评论吧 p5 65 In and Crawling success,time using 0.74319 s
# 财经评论吧 p5 66 In and Crawling success,time using 1.46571 s
# 财经评论吧 p5 67 In and Crawling success,time using 0.84204 s
# 财经评论吧 p5 68 In and Crawling success,time using 0.76970 s
# 财经评论吧 p5 69 In and Crawling success,time using 0.97403 s
# 财经评论吧 p5 70 In and Crawling success,time using 0.80357 s
# 财经评论吧 p5 71 In and Crawling success,time using 1.14849 s
# 财经评论吧 p5 72 In and Crawling success,time using 0.76103 s
# 财经评论吧 p5 73 In and Crawling success,time using 0.99687 s
# 财经评论吧 p5 74 In and Crawling success,time using 0.75390 s
# 财经评论吧 p5 75 In and Crawling success,time using 0.78851 s
# 财经评论吧 p5 76 In and Crawling success,time using 0.66411 s
# 财经评论吧 p5 77 In and Crawling success,time using 0.95002 s
# 财经评论吧 p5 78 In and Crawling success,time using 0.82362 s
# 财经评论吧 p5 79 In and Crawling success,time using 0.83392 s
# 财经评论吧 p5 80 In and Crawling success,time using 1.08313 s
# 财经评论吧 p6 1 In and Crawling success,time using 1.11851 s
# 财经评论吧 p6 2 Out
# 财经评论吧 p6 3 Out
# 财经评论吧 p6 4 Out
# 财经评论吧 p6 5 Out
# 财经评论吧 p6 6 Out
# 财经评论吧 p6 7 Out
# 财经评论吧 p6 8 Out
# 财经评论吧 p6 9 Out
# 财经评论吧 p6 10 Out
# 财经评论吧 p6 11 Out
# 财经评论吧 p6 12 Out
# 财经评论吧 p6 13 Out
# 财经评论吧 p6 14 Out
# 财经评论吧 p6 15 Out
# 财经评论吧 p6 16 Out
# 财经评论吧 p6 17 Out
# 财经评论吧 p6 18 Out
# 财经评论吧 p6 19 Out
# 财经评论吧 p6 20 Out
# 财经评论吧 p6 21 Out
# 财经评论吧 p6 22 Out
# 财经评论吧 p6 23 Out
# 财经评论吧 p6 24 Out
# 财经评论吧 p6 25 Out
# 财经评论吧 p6 26 Out
# 财经评论吧 p6 27 Out
# 财经评论吧 p6 28 Out
# 财经评论吧 p6 29 Out
# 财经评论吧 p6 30 Out
# 财经评论吧 p6 31 Out
# 财经评论吧 p6 32 Out
# 财经评论吧 p6 33 Out
# 财经评论吧 p6 34 Out
# 财经评论吧 p6 35 Out
# 财经评论吧 p6 36 Out
# 财经评论吧 p6 37 Out
# 财经评论吧 p6 38 Out
# 财经评论吧 p6 39 Out
# 财经评论吧 p6 40 Out
# 财经评论吧 p6 41 Out
# 财经评论吧 p6 42 Out
# 财经评论吧 p6 43 Out
# 财经评论吧 p6 44 Out
# 财经评论吧 p6 45 Out
# 财经评论吧 p6 46 Out
# 财经评论吧 p6 47 Out
# 财经评论吧 p6 48 Out
# 财经评论吧 p6 49 Out
# 财经评论吧 p6 50 Out
# 财经评论吧 p6 51 Out
# 财经评论吧 p6 52 Out
# 财经评论吧 p6 53 Out
# 财经评论吧 p6 54 Out
# 财经评论吧 p6 55 Out
# 财经评论吧 p6 56 Out
# 财经评论吧 p6 57 Out
# 财经评论吧 p6 58 Out
# 财经评论吧 p6 59 Out
# 财经评论吧 p6 60 Out
# 财经评论吧 p6 61 Out
# 财经评论吧 p6 62 Out
# 财经评论吧 p6 63 Out
# 财经评论吧 p6 64 Out
# 财经评论吧 p6 65 Out
# 财经评论吧 p6 66 Out
# 财经评论吧 p6 67 Out
# 财经评论吧 p6 68 Out
# 财经评论吧 p6 69 Out
# 财经评论吧 p6 70 Out
# 财经评论吧 p6 71 Out
# 财经评论吧 p6 72 Out
# 财经评论吧 p6 73 Out
# 财经评论吧 p6 74 Out
# 财经评论吧 p6 75 Out
# 财经评论吧 p6 76 Out
# 财经评论吧 p6 77 Out
# 财经评论吧 p6 78 Out
# 财经评论吧 p6 79 Out
# 财经评论吧 p6 80 Out
# 已完成topic 财经评论吧 20180601-20180605的评论爬取
# topic 财经评论吧 all time using 00:07:35
# ------------------- End   Crawl -------------------
# all time using 00:07:35
